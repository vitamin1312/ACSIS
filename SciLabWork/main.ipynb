# %%
[wft1, wfm1, fr1] = wfir('lp', 25, [0.25 0], 'kr', [2.8 0])
# Out:
#  wft1  =
#   -4.688D-18  -0.0093162   7.946D-18   0.0175236  -1.136D-17  -0.0303665   1.457D-17   0.0521632  -1.718D-17  -0.0989051   1.890D-17   0.3158591   0.5   0.3158591   1.890D-17  -0.0989051  -1.718D-17   0.0521632   1.457D-17  -0.0303665  -1.136D-17   0.0175236   7.946D-18  -0.0093162  -4.688D-18
#  wfm1  =
#          column 1 to 67
# ...

# %%
subplot(3, 1, 1)
plot2d(fr1, 10 * log10(wfm1));
xtitle('ФНЧ с окном Кайзера')
[wft2, wfm2, fr2] = wfir('sb', 25, [0.25 0.45], 'hm', [0 0]);
subplot(3, 1, 2)
plot2d(fr2, 10 * log10(wfm2));
xtitle('Фильтр затухания с окном Хэмминга')
[wft3, wfm3, fr3] = wfir('bp', 45, [0.25 0.45], 'hm', [0 0]);
subplot(3, 1, 3)
plot2d(fr1, 20*log10(wfm1), 20*log10(wfm2));
